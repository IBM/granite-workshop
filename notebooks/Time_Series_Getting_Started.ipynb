# %% [markdown]
# # Energy Demand Forecasting with Granite Timeseries (TTM)
#
# TinyTimeMixers (TTMs) are compact pre-trained models for Multivariate Time-Series Forecasting, open-sourced by IBM Research. With less than 1 Million parameters, TTM introduces the notion of the first-ever "tiny" pre-trained models for Time-Series Forecasting. TTM outperforms several popular benchmarks demanding billions of parameters in zero-shot and few-shot forecasting and can easily be fine-tuned for multi-variate forecasts.

# %% [markdown]
# ### Install the TSFM Library
#
# The [granite-tsfm library](https://github.com/ibm-granite/granite-tsfm) provides utilities for working with Time Series Foundation Models (TSFM). Here the pinned version is retrieved and installed.

# %%
# Install the tsfm library
! pip install "tsfm_public[notebooks] @ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9" -U
# Out:
# Collecting tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9
#   Cloning https://github.com/ibm-granite/granite-tsfm.git (to revision v0.2.9) to /private/var/folders/y0/04vm9bms7jn7_ynkkh070h7h0000gn/T/pip-install-aza53lww/tsfm-public_8eb9bcaaac834c6caec8541b990eb2ac
#   Running command git clone --filter=blob:none --quiet https://github.com/ibm-granite/granite-tsfm.git /private/var/folders/y0/04vm9bms7jn7_ynkkh070h7h0000gn/T/pip-install-aza53lww/tsfm-public_8eb9bcaaac834c6caec8541b990eb2ac
#   Running command git checkout -q f856e5bfc739dc23b2a2dace13bbe3b45d21ceee
#   Resolved https://github.com/ibm-granite/granite-tsfm.git to commit f856e5bfc739dc23b2a2dace13bbe3b45d21ceee
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.5.2)
# Requirement already satisfied: transformers[torch]>=4.38.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.45.1)
# Collecting urllib3<2,>=1.26.19
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: deprecated in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.2.14)
# Collecting pandas>=2.2.0
#   Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 20.0 MB/s eta 0:00:0000:0100:01
# Collecting datasets
#   Downloading datasets-3.0.1-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 24.8 MB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 12.2 MB/s eta 0:00:00
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 29.3 MB/s eta 0:00:0000:0100:01
# Collecting plotly
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 33.2 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard
#   Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 35.9 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp310-cp310-macosx_11_0_arm64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 37.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from pandas>=2.2.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from pandas>=2.2.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from pandas>=2.2.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2024.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.66.5)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.4.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.25.1)
# Requirement already satisfied: requests in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.32.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2024.9.11)
# Requirement already satisfied: filelock in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.16.1)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.20.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (24.1)
# Requirement already satisfied: torch in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.4.1)
# Collecting accelerate>=0.26.0
#   Downloading accelerate-0.34.2-py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 20.9 MB/s eta 0:00:00
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-17.0.0-cp310-cp310-macosx_11_0_arm64.whl (27.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 34.0 MB/s eta 0:00:0000:0100:01
# Collecting fsspec[http]<=2024.6.1,>=2023.1.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 17.3 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.0 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.10.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from deprecated->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (8.27.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.2.2)
# Collecting widgetsnbextension~=4.0.12
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.7 MB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-widgets~=3.0.12
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 14.1 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: nbconvert in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (7.16.4)
# Requirement already satisfied: notebook in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (7.2.2)
# Requirement already satisfied: jupyterlab in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.2.5)
# Requirement already satisfied: ipykernel in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (6.29.5)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp310-cp310-macosx_11_0_arm64.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 7.3 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from matplotlib->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (10.4.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.54.1-cp310-cp310-macosx_11_0_arm64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 33.4 MB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp310-cp310-macosx_11_0_arm64.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 22.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from plotly->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (8.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from scikit-learn->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from scikit-learn->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from scikit-learn->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.5.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tensorboard->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (75.1.0)
# Collecting absl-py>=0.4
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 9.2 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 8.7 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tensorboard->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.25.5)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tensorboard->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.66.1)
# Requirement already satisfied: six>1.9 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from tensorboard->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.16.0)
# Requirement already satisfied: psutil in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from accelerate>=0.26.0->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (6.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (24.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.4.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from aiohttp->datasets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.12.2)
# Requirement already satisfied: decorator in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.18.0)
# Requirement already satisfied: pexpect>4.3 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.9.0)
# Requirement already satisfied: exceptiongroup in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.2.2)
# Requirement already satisfied: stack-data in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.0.48)
# Requirement already satisfied: matplotlib-inline in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.1.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from requests->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from requests->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from requests->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2024.8.30)
# Requirement already satisfied: networkx in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from torch->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.3)
# Requirement already satisfied: jinja2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from torch->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.1.4)
# Requirement already satisfied: sympy in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from torch->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.13.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.1.5)
# Requirement already satisfied: appnope in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.1.4)
# Requirement already satisfied: nest-asyncio in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (6.4.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (5.7.2)
# Requirement already satisfied: pyzmq>=24 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (26.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.8.6)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.2.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.14.2)
# Requirement already satisfied: tomli>=1.2.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.0.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.27.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.27.3)
# Requirement already satisfied: beautifulsoup4 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.12.3)
# Requirement already satisfied: defusedxml in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.10.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.3.0)
# Requirement already satisfied: bleach!=5.0.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.0.2)
# Requirement already satisfied: nbformat>=5.7 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (5.10.4)
# Requirement already satisfied: webencodings in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.5.1)
# Requirement already satisfied: sniffio in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.0.5)
# Requirement already satisfied: anyio in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.6.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (23.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.18.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.10.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.8.3)
# Requirement already satisfied: overrides>=5.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.8.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.21.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (4.23.0)
# Requirement already satisfied: babel>=2.10 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.16.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.6)
# Requirement already satisfied: pure-eval in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from sympy->torch->transformers[torch]>=4.38.0->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (21.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2023.12.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.0.7)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (24.8.0)
# Requirement already satisfied: uri-template in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.3.0)
# Requirement already satisfied: isoduration in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (3.0.0)
# Requirement already satisfied: fqdn in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.17.1)
# Requirement already satisfied: pycparser in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/mhickey/.pyenv/versions/3.10.14/envs/test-granite-rag/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.9) (2.9.0.20240906)
# Building wheels for collected packages: tsfm_public
#   Building wheel for tsfm_public (pyproject.toml) ... done
#   Created wheel for tsfm_public: filename=tsfm_public-0.2.9-py3-none-any.whl size=2317360 sha256=b129248e850a52912bca7f73e488006ec7c3fb048130334ace6fa26230ad47c8
#   Stored in directory: /private/var/folders/y0/04vm9bms7jn7_ynkkh070h7h0000gn/T/pip-ephem-wheel-cache-sypcu8ot/wheels/4f/3c/f8/e0e7bf1bc35ada8d515dd3dfe3c14fb1d9fe87c4f64457b26d
# Successfully built tsfm_public
# Installing collected packages: kaleido, xxhash, widgetsnbextension, werkzeug, urllib3, tensorboard-data-server, pyparsing, pyarrow, plotly, markdown, kiwisolver, jupyterlab-widgets, fsspec, fonttools, dill, cycler, contourpy, absl-py, tensorboard, pandas, multiprocess, matplotlib, ipywidgets, accelerate, jupyter-console, datasets, tsfm_public, jupyter
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.9.0
#     Uninstalling fsspec-2024.9.0:
#       Successfully uninstalled fsspec-2024.9.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibm-watsonx-ai 1.1.11 requires pandas<2.2.0,>=0.24.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed absl-py-2.1.0 accelerate-0.34.2 contourpy-1.3.0 cycler-0.12.1 datasets-3.0.1 dill-0.3.8 fonttools-4.54.1 fsspec-2024.6.1 ipywidgets-8.1.5 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-widgets-3.0.13 kaleido-0.2.1 kiwisolver-1.4.7 markdown-3.7 matplotlib-3.9.2 multiprocess-0.70.16 pandas-2.2.3 plotly-5.24.1 pyarrow-17.0.0 pyparsing-3.1.4 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tsfm_public-0.2.9 urllib3-1.26.20 werkzeug-3.0.4 widgetsnbextension-4.0.13 xxhash-3.5.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# ### Import Packages
#
# From `tsfm_public`, we use the TinyTimeMixer model, forecasting pipeline, and plotting function.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from tsfm_public import (
    TinyTimeMixerForPrediction,
    TimeSeriesForecastingPipeline,
)
from tsfm_public.toolkit.visualization import plot_predictions
# Out:
# Matplotlib is building the font cache; this may take a moment.
# INFO:p-81507:t-8364838720:config.py:<module>:PyTorch version 2.4.1 available.

# %% [markdown]
# ### Download the data
#
# We'll work with a dataset of hourly electrical demand, generation by type, prices, and weather in Spain.
#
# Download the energy_data.csv.zip [dataset file from workshop repository.](https://github.com/IBM/granite-workshop/blob/main/data/energy_dataset.csv.zip)
#
# If the notebook is being run locally on your computer then just need to edit the `DATA_FILE_PATH` below to point to the data file.

# %%
DATA_FILE_PATH = "~/Downloads/energy_dataset.csv.zip"

# %% [markdown]
# If the notebook is being run remotely on Google Colab then you need to upload the dataset to the Colab environment.
#
# #### Uploading data in Google Colab
#
# To upload data in Google Colab:
#
# 1. Click on the folder icon on the left of the screen.
#
# ![image.png](./images/collab-folder-icon.png)
#
# 2. Click on the file with an up arrow in it icon, under it.
#
# ![image.png](./images/collab-file-upload-button.png)
#
# 3. Navigate to the _dataset_ file that was downloaded, right click on your uploaded file, then select 'Copy Path'.
#
# ![image.png](./images/collab-copy-path.png)
#
# 4. Edit the `DATA_FILE_PATH` below to point to the data file using the copied path from step above

# %%
DATA_FILE_PATH = "<path>/energy_dataset.csv.zip"

# %% [markdown]
# ### Specify time and output variables
#
# We provide the names of the timestamp column and the target column to be predicted. The context length (in time steps) is set to match the pretrained model.

# %%
timestamp_column = "time"
target_columns = ["total load actual"]
context_length = 512

# %% [markdown]
# ### Read in the data
#
# We parse the csv into a pandas dataframe, filling in any null values, and create a single window containing `context_length` time points. We ensure the timestamp column is a datetime.

# %%
# Read in the data from the downloaded file.
input_df = pd.read_csv(
  DATA_FILE_PATH,
  parse_dates=[timestamp_column], # Parse the timestamp values as dates. 
)

# Fill NA/NaN values by propagating the last valid value.
input_df = input_df.ffill()

# Only use the last `context_length` rows for prediction.
input_df = input_df.iloc[-context_length:,]

# Show the last few rows of the dataset.
input_df.tail()
# Out:
#                             time  generation biomass  \
# 35059  2018-12-31 19:00:00+01:00               297.0
# 35060  2018-12-31 20:00:00+01:00               296.0
# 35061  2018-12-31 21:00:00+01:00               292.0
# 35062  2018-12-31 22:00:00+01:00               293.0
# 35063  2018-12-31 23:00:00+01:00               290.0
#
#        generation fossil brown coal/lignite  \
# 35059                                   0.0
# 35060                                   0.0
# 35061                                   0.0
# 35062                                   0.0
# 35063                                   0.0
#
#        generation fossil coal-derived gas  generation fossil gas  \
# 35059                                 0.0                 7634.0
# 35060                                 0.0                 7241.0
# 35061                                 0.0                 7025.0
# 35062                                 0.0                 6562.0
# 35063                                 0.0                 6926.0
#
#        generation fossil hard coal  generation fossil oil  \
# 35059                       2628.0                  178.0
# 35060                       2566.0                  174.0
# 35061                       2422.0                  168.0
# 35062                       2293.0                  163.0
# 35063                       2166.0                  163.0
#
#        generation fossil oil shale  generation fossil peat  \
# 35059                          0.0                     0.0
# 35060                          0.0                     0.0
# 35061                          0.0                     0.0
# 35062                          0.0                     0.0
# 35063                          0.0                     0.0
#
#        generation geothermal  ...  generation waste  generation wind offshore  \
# 35059                    0.0  ...             277.0                       0.0
# 35060                    0.0  ...             280.0                       0.0
# 35061                    0.0  ...             286.0                       0.0
# 35062                    0.0  ...             287.0                       0.0
# 35063                    0.0  ...             287.0                       0.0
#
#        generation wind onshore  forecast solar day ahead  \
# 35059                   3113.0                      96.0
# 35060                   3288.0                      51.0
# 35061                   3503.0                      36.0
# 35062                   3586.0                      29.0
# 35063                   3651.0                      26.0
#
#        forecast wind offshore eday ahead  forecast wind onshore day ahead  \
# 35059                                NaN                           3253.0
# 35060                                NaN                           3353.0
# 35061                                NaN                           3404.0
# 35062                                NaN                           3273.0
# 35063                                NaN                           3117.0
#
#        total load forecast  total load actual  price day ahead  price actual
# 35059              30619.0            30653.0            68.85         77.02
# 35060              29932.0            29735.0            68.40         76.16
# 35061              27903.0            28071.0            66.88         74.30
# 35062              25450.0            25801.0            63.93         69.89
# 35063              24424.0            24455.0            64.27         69.88
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Plot the target series
#
# Here we inspect a preview of the target time series column.

# %%
fig, axs = plt.subplots(len(target_columns), 1, figsize=(10, 2 * len(target_columns)), squeeze=False)
for ax, target_column in zip(axs, target_columns):
    ax[0].plot(input_df[timestamp_column], input_df[target_column])

# %% [markdown]
# ### Set up zero shot model
# The TTM model is hosted on [HuggingFace](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1), and is retrieved by the wrapper, `TinyTimeMixerForPrediction`. We have one input channel in this example.

# %%
# Instantiate the model.
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained(
  "ibm-granite/granite-timeseries-ttm-v1", # Name of the model on HuggingFace.
  num_input_channels=len(target_columns) # tsp.num_input_channels,
)
# Out:
# config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.24M [00:00<?, ?B/s]

# %% [markdown]
# ### Create a forecasting pipeline
#
# Set up the forecasting pipeline with the model, setting `frequency` given our knowledge of the sample frequency. In this example we set `explode_forecasts` to `True`, which will format the output for plotting the history and prediction period. We then make a forecast on the dataset.

# %%
# Create a pipeline.
pipeline = TimeSeriesForecastingPipeline(
    zeroshot_model,
    timestamp_column=timestamp_column,
    id_columns=[],
    target_columns=target_columns,
    explode_forecasts=True,
    freq="h",
    device="cpu", # Specify your local GPU or CPU.
)

# Make a forecast on the target column given the input data.
zeroshot_forecast = pipeline(input_df)
zeroshot_forecast.tail()
# Out:
#                         time  total load actual_prediction
# 91 2019-01-04 19:00:00+01:00                  31888.005859
# 92 2019-01-04 20:00:00+01:00                  31953.994141
# 93 2019-01-04 21:00:00+01:00                  31226.650391
# 94 2019-01-04 22:00:00+01:00                  29632.421875
# 95 2019-01-04 23:00:00+01:00                  27261.150391

# %% [markdown]
# ### Plot predictions along with the historical data.
#
# The predicted series picks up where the historical data ends, and we can see that it predicts a continuation of the cyclical pattern and an upward trend.

# %%
# Plot the historical data and predicted series.
plot_predictions(
    input_df=input_df,
    exploded_predictions_df=zeroshot_forecast,
    freq="h",
    timestamp_column=timestamp_column,
    channel=target_column,
    indices=[-1],
    num_plots=1,
)
